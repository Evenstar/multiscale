# %%
from sklearn import cross_validation
from sklearn.svm import SVC
import numpy as np,h5py
mat=h5py.File('test_data_1.mat','r')
train_x=np.array(mat.get('seqx')).transpose()
train_y=np.ravel(np.array(mat.get('seqy')))
#import scipy.io
#mat = scipy.io.loadmat('seqy.mat')
#train_y=np.ravel(np.array(mat['seqy']))

# %%
train_x=train_x[0:1000,:]
train_y=train_y[0:1000]
shuffle = np.random.permutation(np.arange(train_x.shape[0]))
train_x, train_y = train_x[shuffle], train_y[shuffle]
clf = SVC(kernel="linear", C=1)
# Train and validate the model with 7-fold cross validation
scores = cross_validation.cross_val_score(clf, train_x, train_y, cv=3)
print scores
# Out:
# [ 0.11976048  0.12012012  0.12312312]

# %%
train_y=np.ravel(np.array(mat['seqy']))

# %%
shuffle
# Out:
# array([605, 572, 320, 828, 222, 601, 749, 873, 902, 849, 969, 951, 602,
#         73, 982, 365, 274, 509, 293, 940, 542, 418, 429, 259, 385, 952,
#        370, 304, 699, 777, 260,  69, 321,  48, 149, 251, 672, 338,  65,
#         77, 885, 136, 153, 924, 965, 347, 860, 871, 675, 163, 821, 745,
#        333, 482, 290, 142, 282, 802, 688, 151, 124,  14,  20, 758,   1,
#        814, 973, 102, 700, 322, 714, 495, 708, 685, 648, 825, 541,  43,
#        883, 625, 750, 389, 706, 502, 818, 104,  53, 868, 101, 146, 468,
#        723, 171, 269, 280, 751, 830, 159, 875, 961, 674, 366, 456, 702,
#        551, 481, 642, 912,  87, 377,  85, 249, 517, 721, 779, 796, 225,
#        263, 959, 558, 906, 373, 478,  83,  66, 577, 111, 548, 962, 283,
#         41, 778, 914, 147, 979,  72,  78, 402, 379, 798, 629, 986, 550,
#        353, 878, 531, 703, 607, 689, 727, 372, 820, 130, 886, 611, 540,
#        399, 756, 858, 740, 893, 501, 362,   8, 561, 426, 636, 400,  27,
#        176, 277,   9, 135, 433, 712, 923, 918,  71, 490, 412, 816, 224,
#         11, 929, 114, 716, 787, 710, 837, 451, 544, 631,  46, 461, 500,
#         54, 804, 100, 398, 217, 127,  15, 460, 543,   4, 533, 233, 704,
#        475, 187, 252, 446, 753, 226, 794, 523, 364, 645, 383, 188, 915,
#        266, 843, 186, 682, 491,  95,  58, 361,  55, 670, 247, 928, 990,
#        799, 618, 763, 846, 665, 285, 152, 390, 303, 177, 944, 329, 327,
#         28, 590, 882, 991, 552, 119, 337, 168, 154, 917, 363, 201,   5,
#        463, 184,  23, 899, 173, 574, 568, 465, 406, 581, 376, 126, 231,
#        445, 462, 632, 190,  37, 459, 323, 123, 595, 374, 403, 732, 985,
#        744, 691, 122, 270,  33, 309, 874, 555, 711, 505, 950, 271, 273,
#        165,  50, 839, 133, 404,  32, 275, 612, 877, 477, 817, 554, 113,
#        655, 956, 911, 848, 800, 314, 493, 579, 279, 592,  80, 503, 317,
#        346, 948, 994, 286, 570, 388, 834, 267, 105, 421, 325, 681, 108,
#        656, 609, 516, 972, 585, 908,  52, 897, 289, 784, 905, 761, 623,
#        235,   7, 596, 731, 920, 356, 673, 129,  99, 244, 218, 678, 479,
#        507,  12, 345, 789,   0, 453, 423, 454, 630, 526, 781, 419, 739,
#        527, 827, 473, 207, 892, 294, 788, 667, 139, 452, 264, 351, 738,
#         40, 511, 866, 564, 772, 287, 826, 386, 562,  16, 515, 599, 214,
#        936, 229, 696, 245,  96, 690, 806, 213, 455, 409, 206, 993, 358,
#        680, 832, 898,  89, 197, 971, 205, 355, 417, 903, 743, 649, 976,
#        842, 198, 474, 472, 730, 894, 326, 646, 583, 297, 210, 587, 211,
#        945, 560,  60, 498, 301, 212, 857, 357, 606, 392, 634, 284,  17,
#        539,  44, 747, 427, 776, 262, 203, 319, 919,  61,  59, 926,  39,
#        764, 208, 856, 938, 428, 414, 904, 610, 431, 257, 790, 415, 783,
#        258, 375, 900, 518, 661, 256, 815, 937, 910, 981, 836, 110, 261,
#        547, 633, 722,  90, 927, 170, 861, 316, 852, 144, 563, 748, 686,
#        405, 668, 591, 824, 947, 450,  64, 729, 344, 999, 430, 984, 801,
#        831, 598, 695, 735, 586, 780,  93, 524,  49, 219, 494, 851, 413,
#        879,  75, 754, 520, 724, 313, 626, 174, 194, 382, 998, 255, 890,
#        569, 765, 182, 896, 391, 992, 508, 921, 935, 980, 145, 966, 872,
#        771,  30, 180, 946, 683, 103,  18, 823,  34, 934, 638, 728])

# %%
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-22-5dfbefab5259> in <module>()
# ----> 1 np.array(mat.get('seqy')).transpose()
#
# /Users/chengtai/anaconda/lib/python2.7/site-packages/h5py/_hl/dataset.pyc in __array__(self, dtype)
#     634             return arr
#     635
# --> 636         self.read_direct(arr)
#     637         return arr
#     638
#
# /Users/chengtai/anaconda/lib/python2.7/site-packages/h5py/_hl/dataset.pyc in read_direct(self, dest, source_sel, dest_sel)
#     599
#     600         for mspace in dest_sel.broadcast(source_sel.mshape):
# --> 601             self.id.read(mspace, fspace, dest)
#     602
#     603     def write_direct(self, source, source_sel=None, dest_sel=None):
#
# /Users/chengtai/anaconda/lib/python2.7/site-packages/h5py/h5d.so in h5py.h5d.DatasetID.read (h5py/h5d.c:2667)()
#
# /Users/chengtai/anaconda/lib/python2.7/site-packages/h5py/_proxy.so in h5py._proxy.dset_rw (h5py/_proxy.c:1573)()
#
# /Users/chengtai/anaconda/lib/python2.7/site-packages/h5py/_proxy.so in h5py._proxy.H5PY_H5Dread (h5py/_proxy.c:1262)()
#
# IOError: Can't read data (Addr overflow, addr = 587749152, size=2616, eoa=587749160)
